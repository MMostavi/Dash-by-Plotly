# %% [markdown]
# boxplot: is divided into 4 different groups. Q1, Q2(median), Q3. Anything above wiskerplot is considered as outliers
#
# violin plot: is built from boxplot. It's a way to pick the distribution of boxplot. KDE is used for the dist

# %% [markdown]
# https://chartio.com/learn/charts/box-plot-complete-guide/
#
# https://chartio.com/learn/charts/violin-plot-complete-guide/
#
# https://plotly.com/python-api-reference/generated/plotly.express.violin.html#plotly.express.violin

# %%
import pandas as pd
import plotly
import plotly.express as px
import plotly.io as pio

# %%
df = pd.read_csv("bees.csv")
df.info()

# %%
mapping = {'HONEY, BEE COLONIES, AFFECTED BY DISEASE - INVENTORY, MEASURED IN PCT OF COLONIES':'Disease',
           'HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES - INVENTORY, MEASURED IN PCT OF COLONIES':'Other',
           'HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - INVENTORY, MEASURED IN PCT OF COLONIES':'Pesticides',
           'HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL VARROA MITES)) - INVENTORY, MEASURED IN PCT OF COLONIES':'Pests_excl_Varroa',
           'HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSES - INVENTORY, MEASURED IN PCT OF COLONIES':'Unknown',
           'HONEY, BEE COLONIES, AFFECTED BY VARROA MITES - INVENTORY, MEASURED IN PCT OF COLONIES':'Varroa_mites'}
df['Data Item'] = df['Data Item'].map(mapping)
df.rename(columns={'Data Item':'Affected by', 'Value':'Percent of Colonies Impacted'}, inplace=True)
print(df[:10][['Year','Period','State','Affected by','Percent of Colonies Impacted']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Data Item'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-c03ca4f81e9b> in <module>
#       5            'HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSES - INVENTORY, MEASURED IN PCT OF COLONIES':'Unknown',
#       6            'HONEY, BEE COLONIES, AFFECTED BY VARROA MITES - INVENTORY, MEASURED IN PCT OF COLONIES':'Varroa_mites'}
# ----> 7 df['Data Item'] = df['Data Item'].map(mapping)
#       8 df.rename(columns={'Data Item':'Affected by', 'Value':'Percent of Colonies Impacted'}, inplace=True)
#       9 print(df[:10][['Year','Period','State','Affected by','Percent of Colonies Impacted']])
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'Data Item'

# %%
df
# Out:
#      Program  Year        Period    State  State ANSI        Affected by  \
# 0     SURVEY  2019  JAN THRU MAR  ALABAMA           1            Disease
# 1     SURVEY  2019  JAN THRU MAR  ALABAMA           1              Other
# 2     SURVEY  2019  JAN THRU MAR  ALABAMA           1         Pesticides
# 3     SURVEY  2019  JAN THRU MAR  ALABAMA           1  Pests_excl_Varroa
# 4     SURVEY  2019  JAN THRU MAR  ALABAMA           1            Unknown
# ...      ...   ...           ...      ...         ...                ...
# 4585  SURVEY  2015  OCT THRU DEC  WYOMING          56              Other
# 4586  SURVEY  2015  OCT THRU DEC  WYOMING          56         Pesticides
# 4587  SURVEY  2015  OCT THRU DEC  WYOMING          56  Pests_excl_Varroa
# 4588  SURVEY  2015  OCT THRU DEC  WYOMING          56            Unknown
# 4589  SURVEY  2015  OCT THRU DEC  WYOMING          56       Varroa_mites
#
#       Percent of Colonies Impacted
# 0                              1.8
# 1                              3.1
# 2                              0.3
# 3                             22.7
# 4                              9.0
# ...                            ...
# 4585                          11.3
# 4586                          10.5
# 4587                           3.3
# 4588                           3.9
# 4589                          45.0
#
# [4590 rows x 7 columns]

# %%
violinfig = px.violin(
    # data_frame=df.query("State == ['{}','{}']".format('ALABAMA','NEW YORK')),
    data_frame=df,
    x="Affected by",
    y="Percent of Colonies Impacted",
    category_orders={'Affected by':['Disease','Unknown','Pesticides','Other','Pests_excl_Varroa','Varroa_mites']},
    orientation="v",              # vertical 'v' or horizontal 'h'
    # points='all',               # 'outliers','suspectedoutliers', 'all', or False
    # box=True,                   # draw box inside the violins
    # color='State',              # differentiate markers by color
    # violinmode="overlay",       # 'overlay' or 'group'
    # color_discrete_sequence=["limegreen","red"],
    # color_discrete_map={"ALABAMA": "blue" ,"NEW YORK":"magenta"}, # map your chosen colors

    # hover_name='Year',          # values appear in bold in the hover tooltip
    # hover_data=['State'],       # values appear as extra data in the hover tooltip
    # custom_data=['Program'],    # values are extra data to be used in Dash callbacks

    # facet_row='State',          # assign marks to subplots in the vertical direction
    # facet_col='Period',         # assign marks to subplots in the horizontal direction
    # facet_col_wrap=2,           # maximum number of subplot columns. Do not set facet_row

    # log_x=True,                 # x-axis is log-scaled
    # log_y=True,                 # y-axis is log-scaled

    labels={"State":"STATE"},     # map the labels
    title='What is killing our Bees',
    width=900,                   # figure width in pixels
    height=600,                   # igure height in pixels
    template='presentation',      # 'ggplot2', 'seaborn', 'simple_white', 'plotly',
                                  # 'plotly_white', 'plotly_dark', 'presentation',
                                  # 'xgridoff', 'ygridoff', 'gridon', 'none'

    # animation_frame='Year',     # assign marks to animation frames
    # animation_group='',         # use only when df has multiple rows with same object
    # range_x=[5,50],             # set range of x-axis
    # range_y=[-5,100],           # set range of y-axis
    # category_orders={'Year':[2015,2016,2017,2018,2019]},    # set a specific ordering of values per column
)

# violinfig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 1000

# violinfig.update_layout(
#         yaxis = dict(
#         tickfont=dict(size=8)))

pio.show(violinfig)
# Out:
# <div>                            <div id="03bd5272-71aa-4858-b1ec-882ca6047f00" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03bd5272-71aa-4858-b1ec-882ca6047f00")) {                    Plotly.newPlot(                        "03bd5272-71aa-4858-b1ec-882ca6047f00",                        [{"alignmentgroup": "True", "box": {"visible": false}, "hovertemplate": "Affected by=%{x}<br>Percent of Colonies Impacted=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#1F77B4"}, "name": "", "offsetgroup": "", "orientation": "v", "scalegroup": "True", "showlegend": false, "type": "violin", "x": ["Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests ...

# %%
violinfig = px.violin(
    # data_frame=df.query("State == ['{}','{}']".format('ALABAMA','NEW YORK')),
    data_frame=df,
    y="Affected by",
    x="Percent of Colonies Impacted",
    category_orders={'Affected by':['Disease','Unknown','Pesticides','Other','Pests_excl_Varroa','Varroa_mites']},
    orientation="h",              # vertical 'v' or horizontal 'h'
    # points='all',               # 'outliers','suspectedoutliers', 'all', or False
    # box=True,                   # draw box inside the violins
    # color='State',              # differentiate markers by color
    # violinmode="overlay",       # 'overlay' or 'group'
    # color_discrete_sequence=["limegreen","red"],
    # color_discrete_map={"ALABAMA": "blue" ,"NEW YORK":"magenta"}, # map your chosen colors

    # hover_name='Year',          # values appear in bold in the hover tooltip
    # hover_data=['State'],       # values appear as extra data in the hover tooltip
    # custom_data=['Program'],    # values are extra data to be used in Dash callbacks

    # facet_row='State',          # assign marks to subplots in the vertical direction
    # facet_col='Period',         # assign marks to subplots in the horizontal direction
    # facet_col_wrap=2,           # maximum number of subplot columns. Do not set facet_row

    # log_x=True,                 # x-axis is log-scaled
    # log_y=True,                 # y-axis is log-scaled

    labels={"State":"STATE"},     # map the labels
    title='What is killing our Bees',
    width=1000,                   # figure width in pixels
    height=600,                   # igure height in pixels
    template='presentation',      # 'ggplot2', 'seaborn', 'simple_white', 'plotly',
                                  # 'plotly_white', 'plotly_dark', 'presentation',
                                  # 'xgridoff', 'ygridoff', 'gridon', 'none'

    # animation_frame='Year',     # assign marks to animation frames
    # animation_group='',         # use only when df has multiple rows with same object
    # range_x=[5,50],             # set range of x-axis
    # range_y=[-5,100],           # set range of y-axis
    # category_orders={'Year':[2015,2016,2017,2018,2019]},    # set a specific ordering of values per column
)

# violinfig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 1000

# violinfig.update_layout(
#         yaxis = dict(
#         tickfont=dict(size=8)))

pio.show(violinfig)
# Out:
# <div>                            <div id="5c0f5ce2-8632-4a63-b138-ab055d5857ab" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c0f5ce2-8632-4a63-b138-ab055d5857ab")) {                    Plotly.newPlot(                        "5c0f5ce2-8632-4a63-b138-ab055d5857ab",                        [{"alignmentgroup": "True", "box": {"visible": false}, "hovertemplate": "Percent of Colonies Impacted=%{x}<br>Affected by=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#1F77B4"}, "name": "", "offsetgroup": "", "orientation": "h", "scalegroup": "True", "showlegend": false, "type": "violin", "x": [1.8, 3.1, 0.3, 22.7, 9.0, 27.2, 1.9, 8.6, 14.9, 30.2, 4.5, 29.2, 1.3, 9.4, 14.4, 27.3, 2.1, 25.2, 0.7, 7.8, 14.6, 69.4, 6.8, 77.5, 1.3, 3.4, 1.5, 20.5, 7.5, 20.6, 0.2, 6.7, 3.2, 9.8, 9.3, 19.9, 0.0, 9.4, 4.2, 13.6, 5.3, 17.9, 0.0, 7.5, 35.4, 22.1, 3.9, 69.5, 8.8, 1.7, 9.5, 10.1, 5.2, 22.3, 4.3, 2.4, 8.1, 22.0, 11.3, 24.2, 0.3, 4.8, 1.7, 8.2, 5.4, 9.6, 0.0, 3.2, 3.8, 42.0, 13.8, 11.7, 0.2, 6.7, 2.4, 9.9, 3.3, 12.3, 0.0, 9.1, 2.2, 5.4, 9.4, 10.0, 0.0, 3.2, 2.3, 42.5, 4.1, 16.7, 0.0, 2.2, 2.6, 70.6, 17.7, 63.1, 0.2, 2.8, 0.2, 6.4, 1.9, 3.1, 6.5, 8.4, 16.2, 7.9, 0.2, 25.8, 4.6, 7.9, 15.3, 4.3, 4.2, 36.3, 32.8, 14.3, 0.8, 7.2, 4.1, 73.8, 4.5, 15.0, 3.8, 2.3, 27.6, 52.5, 3.1, 7.1, 0.0, 8.3, 3.0, 20.6, 3.8, 6.5, 1.7, 2.0, 2.1, 35.6, 19.7, 20.4, 12.4, 15.9, 0.7, 58.4, 0.5, 12.4, 1.1, 0.4, 6.3, 19.8, 2.3, 4.1, 1.6, 4.2, 0.1, 61.6, 0.0, 6.5, 7.7, 2.8, 7.2, 33.8, 17.2, 17.4, 12.0, 47.5, 3.5, 26.8, 0.9, 13.4, 13.5, 1.0, 8.9, 41.7, 2.3, 4.3, 6.5, 15.5, 3.2, 98.8, 0.1, 1.8, 0.0, 20.5, 3.1, 26.9, 0.5, 28.2, 20.1, 32.1, 0.3, 8.4, 5.4, 7.6, 17.3, 24.8, 5.1, 53.5, 1.1, 0.5, 3.5, 1.7, 15.5, 50.1, 3.3, 0.7, 55.3, 1.5, 2.9, 19.5, 1.0, 4.6, 23.0, 9.6, 13.9, 21.1, 0.7, 17.0, 2.2, 12.8, 13.2, 30.9, 0.1, 0.5, 17.6, 7.8, 0.6, 29.9, 0.0, 5.3, 73.5, 7.1, 2.2, 82.8, 0.1, 3.0, 0.5, 14.6, 1.0, 31.5, 1.9, 2.7, 3.9, 9.6, 2.5, 19.4, 0.0, 9.3, 17.0, 9.1, 2.3, 61.4, 26.6, 24.1, 31.0, 29.2, 0.4, 37.5, 0.0, 1.9, 0.5, 6.9, 8.1, 57.4, 5.5, 3.4, 0.1, 8.5, 1.6, 84.9, 0.4, 2.7, 7.9, 9.0, 0.3, 80.7, 0.0, 1.1, 1.3, 4.8, 3.3, 21.1, 1.5, 1.0, 3.4, 11.4, 1.0, 17.6, 7.0, 27.4, 22.6, 63.4, 9.3, 65.9, 0.9, 1.8, 5.0, 32.4, 1.4, 69.2, 0.1, 8.5, 8.2, 9.7, 0.6, 38.1, 6.4, 8.7, 12.3, 13.4, 5.6, 43.5, 4.8, 8.0, 11.5, 11.3, 4.9, 41.3, 11.1, 9.0, 13.7, 10.2, 5.0, 41.5, 4.5, 12.0, 17.8, 6.6, 3.6, 57.3, 9.8, 9.3, 11.6, 16.6, 7.1, 44.1, 7.5, 6.6, 9.2, 12.6, 6.3, 37.7, 3.1, 4.8, 13.0, 7.7, 3.4, 38.0, 5.6, 10.1, 13.4, 15.8, 3.6, 42.3, 7.4, 17.1, 17.0, 14.1, 6.3, 47.9, 9.0, 8.4, 13.5, 15.2, 4.4, 38.1, 11.2, 15.3, 14.2, 14.1, 2.6, 49.7, 8.5, 10.4, 18.8, 17.8, 6.9, 42.2, 8.0, 9.6, 9.1, 13.7, 3.5, 41.9, 3.0, 6.5, 7.5, 7.2, 2.8, 24.7, 7.8, 14.2, 23.0, 21.5, 3.1, 50.9, 12.5, 15.0, 19.6, 20.4, 4.7, 39.9, 6.2, 10.5, 11.7, 12.7, 7.3, 37.3, 0.0, 2.5, 0.0, 0.3, 0.6, 11.2, 3.8, 13.7, 0.5, 0.8, 2.4, 31.7, 12.7, 4.2, 3.6, 0.0, 0.5, 41.7, 5.6, 8.5, 2.9, 16.6, 4.5, 72.6, 1.0, 6.1, 0.0, 5.9, 1.2, 73.2, 0.0, 2.6, 0.9, 0.0, 0.4, 17.0, 5.3, 4.6, 3.2, 0.8, 0.1, 31.3, 2.6, 7.8, 9.1, 1.4, 1.4, 52.9, 0.2, 15.5, 20.0, 0.7, 5.3, 30.2, 0.5, 2.7, 0.2, 4.1, 0.2, 2.9, 3.3, 2.6, 1.4, 0.8, 0.3, 38.7, 16.8, 10.6, 24.6, 22.4, 0.1, 49.3, 0.1, 13.0, 3.1, 1.3, 0.1, 32.4, 1.8, 2.6, 0.6, 0.9, 5.9, 14.6, 4.6, 3.4, 2.8, 1.8, 6.6, 38.6, 2.7, 3.7, 16.5, 1.5, 2.7, 50.5, 21.2, 8.4, 19.7, 24.4, 1.8, 47.6, 0.0, 3.6, 0.0, 1.3, 1.7, 10.1, 0.0, 7.7, 0.8, 0.7, 3.5, 14.5, 0.4, 0.8, 0.8, 0.9, 0.4, 11.1, 0.0, 2.5, 1.4, 0.0, 1.2, 13.0, 2.3, 4.2, 0.9, 3.6, 2.3, 12.5, 0.0, 6.1, 0.0, 1.5, 5.6, 51.5, 0.0, 1.9, 0.5, 0.2, 0.7, 9.1, 0.1, 13.0, 0.0, 1.5, 0.0, 25.1, 0.0, 1.6, 0.6, 2.8, 1.6, 36.4, 0.2, 7.7, 0.0, 0.8, 1.7, 12.3, 0.5, 4.4, 0.3, 0.6, 1.2, 9.3, 0.0, 5.0, 0.2, 1.6, 0.8, 18.8, 1.1, 5.8, 1.0, 6.6, 3.2, 14.7, 0.0, 2 ...

# %%
violinfig = px.violin(
    # data_frame=df.query("State == ['{}','{}']".format('ALABAMA','NEW YORK')),
    data_frame=df,
    x="Affected by",
    y="Percent of Colonies Impacted",
    category_orders={'Affected by':['Disease','Unknown','Pesticides','Other','Pests_excl_Varroa','Varroa_mites']},
    orientation="v",              # vertical 'v' or horizontal 'h'
    points='outliers',               # 'outliers','suspectedoutliers', 'all', or False
    box=True,                   # draw box inside the violins
    # color='State',              # differentiate markers by color
    # violinmode="overlay",       # 'overlay' or 'group'
    # color_discrete_sequence=["limegreen","red"],
    # color_discrete_map={"ALABAMA": "blue" ,"NEW YORK":"magenta"}, # map your chosen colors

    # hover_name='Year',          # values appear in bold in the hover tooltip
    # hover_data=['State'],       # values appear as extra data in the hover tooltip
    # custom_data=['Program'],    # values are extra data to be used in Dash callbacks

    # facet_row='State',          # assign marks to subplots in the vertical direction
    # facet_col='Period',         # assign marks to subplots in the horizontal direction
    # facet_col_wrap=2,           # maximum number of subplot columns. Do not set facet_row

    # log_x=True,                 # x-axis is log-scaled
    # log_y=True,                 # y-axis is log-scaled

    labels={"State":"STATE"},     # map the labels
    title='What is killing our Bees',
    width=1000,                   # figure width in pixels
    height=600,                   # igure height in pixels
    template='presentation',      # 'ggplot2', 'seaborn', 'simple_white', 'plotly',
                                  # 'plotly_white', 'plotly_dark', 'presentation',
                                  # 'xgridoff', 'ygridoff', 'gridon', 'none'

    # animation_frame='Year',     # assign marks to animation frames
    # animation_group='',         # use only when df has multiple rows with same object
    # range_x=[5,50],             # set range of x-axis
    # range_y=[-5,100],           # set range of y-axis
    # category_orders={'Year':[2015,2016,2017,2018,2019]},    # set a specific ordering of values per column
)

# violinfig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 1000

# violinfig.update_layout(
#         yaxis = dict(
#         tickfont=dict(size=8)))

pio.show(violinfig)
# Out:
# <div>                            <div id="485418f8-7745-4485-9b91-7e9bc3f9dec2" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("485418f8-7745-4485-9b91-7e9bc3f9dec2")) {                    Plotly.newPlot(                        "485418f8-7745-4485-9b91-7e9bc3f9dec2",                        [{"alignmentgroup": "True", "box": {"visible": true}, "hovertemplate": "Affected by=%{x}<br>Percent of Colonies Impacted=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#1F77B4"}, "name": "", "offsetgroup": "", "orientation": "v", "points": "outliers", "scalegroup": "True", "showlegend": false, "type": "violin", "x": ["Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other" ...

# %%
violinfig = px.violin(
    data_frame=df.query("State == ['{}','{}']".format('ALABAMA','NEW YORK')),
#     data_frame=df,
    x="Affected by",
    y="Percent of Colonies Impacted",
    category_orders={'Affected by':['Disease','Unknown','Pesticides','Other','Pests_excl_Varroa','Varroa_mites']},
    orientation="v",              # vertical 'v' or horizontal 'h'
    points='all',               # 'outliers','suspectedoutliers', 'all', or False
#     box=True,                   # draw box inside the violins
    color='State',              # differentiate markers by color
    violinmode="group",       # 'overlay' or 'group'
    # color_discrete_sequence=["limegreen","red"],
    # color_discrete_map={"ALABAMA": "blue" ,"NEW YORK":"magenta"}, # map your chosen colors

    hover_name='Year',          # values appear in bold in the hover tooltip
    hover_data=['State'],       # values appear as extra data in the hover tooltip
    # custom_data=['Program'],    # values are extra data to be used in Dash callbacks

#     facet_row='State',          # assign marks to subplots in the vertical direction
#     facet_col='State',         # assign marks to subplots in the horizontal direction
#     facet_col_wrap=5,           # maximum number of subplot columns. Do not set facet_row

    # log_x=True,                 # x-axis is log-scaled
    # log_y=True,                 # y-axis is log-scaled

    labels={"State":"STATE"},     # map the labels
    title='What is killing our Bees',
    width=1000,                   # figure width in pixels
    height=600,                   # igure height in pixels
    template='presentation',      # 'ggplot2', 'seaborn', 'simple_white', 'plotly',
                                  # 'plotly_white', 'plotly_dark', 'presentation',
                                  # 'xgridoff', 'ygridoff', 'gridon', 'none'

    # animation_frame='Year',     # assign marks to animation frames
    # animation_group='',         # use only when df has multiple rows with same object
    # range_x=[5,50],             # set range of x-axis
    # range_y=[-5,100],           # set range of y-axis
    # category_orders={'Year':[2015,2016,2017,2018,2019]},    # set a specific ordering of values per column
)

# violinfig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 1000

# violinfig.update_layout(
#         yaxis = dict(
#         tickfont=dict(size=8)))

pio.show(violinfig)
# Out:
# <div>                            <div id="f1525c69-8ea9-4384-9880-efdb46d181a0" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1525c69-8ea9-4384-9880-efdb46d181a0")) {                    Plotly.newPlot(                        "f1525c69-8ea9-4384-9880-efdb46d181a0",                        [{"alignmentgroup": "True", "box": {"visible": false}, "customdata": [["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"]], "hovertemplate": "<b>%{hovertext}</b><br><br>STATE=%{customdata[0]}<br>Affected by=%{x}<br>Percent of Colonies Impacted=%{y}<extra></extra>", "hovertext": [2019.0, 2019.0, 2019.0, 2019.0, 2019.0, 2019.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2018.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2017.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0, 2015.0], "legendgroup": "ALABAMA", "marker": {"color": "#1F77B4"}, "name": "ALABAMA", "offsetgroup": "ALABAMA", "orientation": "v", "points": "all", "scalegroup": "True", "showlegend": true, "type": "violin", "x": ["Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varroa_mites", "Disease", "Other", "Pesticides", "Pests_excl_Varroa", "Unknown", "Varro ...

# %%
df
# Out:
#      Program  Year        Period    State  State ANSI        Affected by  \
# 0     SURVEY  2019  JAN THRU MAR  ALABAMA           1            Disease
# 1     SURVEY  2019  JAN THRU MAR  ALABAMA           1              Other
# 2     SURVEY  2019  JAN THRU MAR  ALABAMA           1         Pesticides
# 3     SURVEY  2019  JAN THRU MAR  ALABAMA           1  Pests_excl_Varroa
# 4     SURVEY  2019  JAN THRU MAR  ALABAMA           1            Unknown
# ...      ...   ...           ...      ...         ...                ...
# 4585  SURVEY  2015  OCT THRU DEC  WYOMING          56              Other
# 4586  SURVEY  2015  OCT THRU DEC  WYOMING          56         Pesticides
# 4587  SURVEY  2015  OCT THRU DEC  WYOMING          56  Pests_excl_Varroa
# 4588  SURVEY  2015  OCT THRU DEC  WYOMING          56            Unknown
# 4589  SURVEY  2015  OCT THRU DEC  WYOMING          56       Varroa_mites
#
#       Percent of Colonies Impacted
# 0                              1.8
# 1                              3.1
# 2                              0.3
# 3                             22.7
# 4                              9.0
# ...                            ...
# 4585                          11.3
# 4586                          10.5
# 4587                           3.3
# 4588                           3.9
# 4589                          45.0
#
# [4590 rows x 7 columns]

# %%
violinfig = px.violin(
#     data_frame=df.query("State == ['{}','{}']".format('ALABAMA','NEW YORK')),
    data_frame=df,
    x="Affected by",
    y="Percent of Colonies Impacted",
#     category_orders={'Affected by':['Disease','Unknown','Pesticides','Other','Pests_excl_Varroa','Varroa_mites']},
    orientation="v",              # vertical 'v' or horizontal 'h'
    points='all',               # 'outliers','suspectedoutliers', 'all', or False
#     box=True,                   # draw box inside the violins
#     color='State',              # differentiate markers by color
#     violinmode="group",       # 'overlay' or 'group'
    # color_discrete_sequence=["limegreen","red"],
    # color_discrete_map={"ALABAMA": "blue" ,"NEW YORK":"magenta"}, # map your chosen colors

#     hover_name='Year',          # values appear in bold in the hover tooltip
    hover_data=['State'],       # values appear as extra data in the hover tooltip
    # custom_data=['Program'],    # values are extra data to be used in Dash callbacks

#     facet_row='State',          # assign marks to subplots in the vertical direction
#     facet_col='State',         # assign marks to subplots in the horizontal direction
#     facet_col_wrap=5,           # maximum number of subplot columns. Do not set facet_row

    # log_x=True,                 # x-axis is log-scaled
    # log_y=True,                 # y-axis is log-scaled

    labels={"State":"STATE"},     # map the labels
    title='What is killing our Bees',
    width=1000,                   # figure width in pixels
    height=600,                   # igure height in pixels
    template='presentation',      # 'ggplot2', 'seaborn', 'simple_white', 'plotly',
                                  # 'plotly_white', 'plotly_dark', 'presentation',
                                  # 'xgridoff', 'ygridoff', 'gridon', 'none'

    animation_frame='Year',     # assign marks to animation frames
    # animation_group='',         # use only when df has multiple rows with same object
#     range_x=[5,50],             # set range of x-axis
    range_y=[-5,100],           # set range of y-axis
    category_orders={'Year':[2015,2016,2017,2018,2019]},    # set a specific ordering of values per column
)

violinfig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 1000

# violinfig.update_layout(
#         yaxis = dict(
#         tickfont=dict(size=8)))

pio.show(violinfig)
# Out:
# <div>                            <div id="d1d13f1b-075e-4cd1-b316-10d9a2941379" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1d13f1b-075e-4cd1-b316-10d9a2941379")) {                    Plotly.newPlot(                        "d1d13f1b-075e-4cd1-b316-10d9a2941379",                        [{"alignmentgroup": "True", "box": {"visible": false}, "customdata": [["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ALABAMA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARIZONA"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["ARKANSAS"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["CALIFORNIA"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["COLORADO"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["CONNECTICUT"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["FLORIDA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["GEORGIA"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["HAWAII"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["IDAHO"], ["ILLINOIS"], ["ILLINOIS"], ["ILLINOIS"], ["ILLINOIS"], ["ILLINOIS"], ["ILLINOIS"], ["ILLINOIS"], ["ILLINOIS"], ["ILLINOIS"], ["ILLINO ...
